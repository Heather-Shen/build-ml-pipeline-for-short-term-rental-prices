# %%
import wandb
import pandas as pd

run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# wandb: Currently logged in as: heather-mck (use `wandb login --relogin` to force relogin)
# /Users/heather_shen/opt/anaconda3/envs/nyc_airbnb_dev/lib/python3.9/site-packages/IPython/html.py:12: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   warn("The `IPython.html` package has been deprecated since IPython 4.0. "
# wandb: wandb version 0.13.10 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                 Tracking run with wandb version 0.10.31<br/>
#                 Syncing run <strong style="color:#cdcd00">spring-oath-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/heather-mck/nyc_airbnb" target="_blank">https://wandb.ai/heather-mck/nyc_airbnb</a><br/>
#                 Run page: <a href="https://wandb.ai/heather-mck/nyc_airbnb/runs/2kxvo6l0" target="_blank">https://wandb.ai/heather-mck/nyc_airbnb/runs/2kxvo6l0</a><br/>
#                 Run data is saved locally in <code>/Users/heather_shen/Documents/Trainings/AEP/RentPrices_MLOps/build-ml-pipeline-for-short-term-rental-prices/wandb/run-20230222_124706-2kxvo6l0</code><br/><br/>

# %%
import pandas_profiling

profile = pandas_profiling.ProfileReport(df)
profile.to_widgets()
# Out:
# Summarize dataset: 100%|██████████| 126/126 [00:08<00:00, 14.43it/s, Completed]
# Generate report structure: 100%|██████████| 1/1 [00:02<00:00,  2.28s/it]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
#                                       id   host_id  latitude  longitude  \
# id                              1.000000  0.552194 -0.007711   0.079560
# host_id                         0.552194  1.000000  0.034685   0.123345
# latitude                       -0.007711  0.034685  1.000000   0.048004
# longitude                       0.079560  0.123345  0.048004   1.000000
# price                          -0.045805 -0.102088  0.131985  -0.418123
# minimum_nights                 -0.072732 -0.146815  0.016233  -0.122840
# number_of_reviews              -0.301818 -0.114044 -0.032348   0.072042
# reviews_per_month               0.364916  0.271438 -0.030284   0.127122
# calculated_host_listings_count  0.135605  0.142490 -0.001741   0.067613
# availability_365                0.157296  0.163726 -0.020017   0.080296
# neighbourhood_group             0.060242  0.101842  0.536548   0.647165
# room_type                       0.073124  0.099374  0.104121   0.142159
#
#                                    price  minimum_nights  number_of_reviews  \
# id                             -0.045805       -0.072732          -0.301818
# host_id                        -0.102088       -0.146815          -0.114044
# latitude                        0.131985        0.016233          -0.032348
# longitude                      -0.418123       -0.122840           0.072042
# price                           1.000000        0.105951          -0.020394
# minimum_nights                  0.105951        1.000000          -0.163825
# number_of_reviews              -0.020394       -0.163825           1.000000
# reviews_per_month              -0.019523       -0.292265           0.707321
# calculated_host_listings_count -0.118070        0.063451           0.065840
# availability_365                0.058826        0.077804           0.256537
# neighbourhood_group             0.180662        0.000000           0.025889
# room_type                       0.496893        0.020526           0.000000
#
#                                 reviews_per_month  \
# id                                       0.364916
# host_id                                  0.271438
# latitude                                -0.030284
# longitude                                0.127122
# price                                   -0.019523
# minimum_nights                          -0.292265
# number_of_reviews                        0.707321
# reviews_per_month                        1.000000
# calculated_host_listings_count           0.153368
# availability_365                         0.396941
# neighbourhood_group                      0.067091
# room_type                                0.015555
#
#                                 calculated_host_listings_count  \
# id                                                    0.135605
# host_id                                               0.142490
# latitude                                             -0.001741
# longitude                                             0.067613
# price                                                -0.118070
# minimum_nights                                        0.063451
# number_of_reviews                                     0.065840
# reviews_per_month                                     0.153368
# calculated_host_listings_count                        1.000000
# availability_365                                      0.411032
# neighbourhood_group                                   0.085134
# room_type                                             0.094443
#
#                                 availability_365  neighbourhood_group  \
# id                                      0.157296             0.060242
# host_id                                 0.163726             0.101842
# latitude                               -0.020017             0.536548
# longitude                               0.080296             0.647165
# price                                   0.058826             0.180662
# minimum_nights                          0.077804             0.000000
# number_of_reviews                       0.256537             0.025889
# reviews_per_month                       0.396941             0.067091
# calculated_host_listings_count          0.411032             0.085134
# availability_365                        1.000000             0.078589
# neighbourhood_group                     0.078589             1.000000
# room_type                               0.092727             0.114948
#
#                                 room_type
# id                               0.073124
# host_id                          0.099374
# latitude                         0.104121
# longitude                        0.142159
# price                            0.496893
# minimum_nights                   0.020526
# number_of_reviews                0.000000
# reviews_per_month                0.015555
# calculated_host_listings_count   0.094443
# availability_365                 0.092727
# neighbourhood_group              0.114948
# room_type                        1.000000
#          id                                               name    host_id  \
# 0   9138664                Private Lg Room 15 min to Manhattan   47594947
# 1  31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 2   8741020  Voted #1 Location Quintessential 1BR W Village...   45854238
# 3  34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 4  23203149   Big beautiful bedroom in huge Bushwick apartment     143460
# 5   4402805         LRG 2br BKLYN APT CLOSE TO TRAINS AND PARK   22807362
# 6  30070126  ✩Prime Renovated 1/1 Apartment in Upper East S...    4968673
# 7  34231172      Fully renovated brick house floor in Brooklyn   59642348
# 8   5856760         Renovated 1BR in exciting, convenient area   29408349
# 9   7929441                 Beautiful Loft w/ Waterfront View!    1453898
#
#   host_name neighbourhood_group              neighbourhood  latitude  \
# 0      Iris              Queens                  Sunnyside  40.74271
# 1    Johlex           Manhattan             Hell's Kitchen  40.76682
# 2      John           Manhattan               West Village  40.73631
# 3     Regan              Queens                    Astoria  40.76424
# 4     Megan            Brooklyn                   Bushwick  40.69839
# 5     Jenny            Brooklyn  Prospect-Lefferts Gardens  40.66025
# 6      Sean           Manhattan            Upper East Side  40.76831
# 7     Kevin            Brooklyn                Sunset Park  40.64550
# 8      Chad           Manhattan                  Chinatown  40.71490
# 9   Anthony            Brooklyn               Williamsburg  40.71268
#
#    longitude        room_type  price  minimum_nights  number_of_reviews  \
# 0  -73.92493     Private room     74               2                  6
# 1  -73.98878  Entire home/apt    170               3                  0
# 2  -74.00611  Entire home/apt    245               3                 51
# 3  -73.92351  Entire home/apt    125               3                  1
# 4  -73.92044     Private room     65               2                  8
# 5  -73.96270  Entire home/apt    120               3                  3
# 6  -73.95929  Entire home/apt    200               5                  2
# 7  -74.01262  Entire home/apt     95               1                  9
# 8  -73.99976  Entire home/apt    179               5                  7
# 9  -73.96676     Private room    105               2                232
#
#   last_review  reviews_per_month  calculated_host_listings_count  \
# 0  2019-05-26               0.13                               1
# 1         NaT                NaN                               1
# 2  2018-09-19               1.12                               1
# 3  2019-05-24               0.65                               1
# 4  2019-06-23               0.52                               2
# 5  2018-08-28               0.05                               1
# 6  2019-05-26               0.68                               1
# 7  2019-07-08               9.00                               1
# 8  2017-04-18               0.14                               1
# 9  2019-06-19               5.00                               3
#
#    availability_365
# 0                 5
# 1               188
# 2                 0
# 3                13
# 4                 8
# 5                16
# 6                71
# 7               106
# 8                 0
# 9                64
#              id                                               name    host_id  \
# 19990   5192459                   Quiet Room in 4BR UWS Brownstone   10677483
# 19991   1327940                 Huge Gorgeous Park View Apartment!    3290436
# 19992  23612681   Shared Room 1 Stop from Manhattan on the F Train   55724558
# 19993  34485745           Midtown Manhattan Stunner - Private room  261632622
# 19994  25616250  Stylish, spacious, private 1BR apt in Ditmas Park  125396920
# 19995   7094539                  Tranquil haven in bubbly Brooklyn    2052211
# 19996   4424261                    Large 1 BR with backyard on UWS    3447311
# 19997   4545882                Amazing studio/Loft with a backyard   23569951
# 19998  26518547          U2 comfortable double bed sleeps 2 guests     295128
# 19999  33631782               Private Bedroom in Williamsburg Apt!    8569221
#
#           host_name neighbourhood_group     neighbourhood  latitude  \
# 19990          Greg           Manhattan   Upper West Side  40.80173
# 19991         Hadar            Brooklyn          Flatbush  40.65335
# 19992        Taylor              Queens  Long Island City  40.76006
# 19993      Royalton           Manhattan  Theater District  40.75491
# 19994          Adam            Brooklyn          Flatbush  40.64314
# 19995       Adriana            Brooklyn   Windsor Terrace  40.65360
# 19996         Sarah           Manhattan   Upper West Side  40.80188
# 19997         Kaveh           Manhattan   Upper East Side  40.78110
# 19998  Carol Gloria               Bronx      Clason Point  40.81225
# 19999          Andi            Brooklyn      Williamsburg  40.71829
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# 19990  -73.96625     Private room     70               1                  0
# 19991  -73.96257  Entire home/apt    120               3                 13
# 19992  -73.94080     Private room     55               4                  2
# 19993  -73.98507     Private room    100               1                  3
# 19994  -73.95705  Entire home/apt     75               3                 10
# 19995  -73.97546  Entire home/apt    143              14                  2
# 19996  -73.96808  Entire home/apt    200               2                 22
# 19997  -73.94567  Entire home/apt    220               3                 28
# 19998  -73.85502     Private room     80               1                  4
# 19999  -73.95819     Private room    109               3                  3
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 19990         NaT                NaN                               1
# 19991  2016-08-27               0.28                               2
# 19992  2019-06-01               0.65                               5
# 19993  2019-06-16               3.00                               9
# 19994  2019-01-03               0.84                               1
# 19995  2016-08-27               0.04                               1
# 19996  2019-05-21               0.50                               1
# 19997  2019-05-23               0.50                               1
# 19998  2019-07-01               1.48                               7
# 19999  2019-04-28               1.07                               2
#
#        availability_365
# 19990                 0
# 19991               327
# 19992                89
# 19993               318
# 19994                 0
# 19995                10
# 19996                 0
# 19997               293
# 19998               365
# 19999                97
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19001 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19001 non-null  int64
#  1   name                            18994 non-null  object
#  2   host_id                         19001 non-null  int64
#  3   host_name                       18993 non-null  object
#  4   neighbourhood_group             19001 non-null  object
#  5   neighbourhood                   19001 non-null  object
#  6   latitude                        19001 non-null  float64
#  7   longitude                       19001 non-null  float64
#  8   room_type                       19001 non-null  object
#  9   price                           19001 non-null  int64
#  10  minimum_nights                  19001 non-null  int64
#  11  number_of_reviews               19001 non-null  int64
#  12  last_review                     15243 non-null  datetime64[ns]
#  13  reviews_per_month               15243 non-null  float64
#  14  calculated_host_listings_count  19001 non-null  int64
#  15  availability_365                19001 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 3.0+ MB

# %%
run.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 79278<br/>Program ended successfully.
# Find user logs for this run at: <code>/Users/heather_shen/Documents/Trainings/AEP/RentPrices_MLOps/build-ml-pipeline-for-short-term-rental-prices/wandb/run-20230222_124706-2kxvo6l0/logs/debug.log</code>
# Find internal logs for this run at: <code>/Users/heather_shen/Documents/Trainings/AEP/RentPrices_MLOps/build-ml-pipeline-for-short-term-rental-prices/wandb/run-20230222_124706-2kxvo6l0/logs/debug-internal.log</code>
# Synced 6 W&B file(s), 0 media file(s), 5 artifact file(s) and 1 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">spring-oath-4</strong>: <a href="https://wandb.ai/heather-mck/nyc_airbnb/runs/2kxvo6l0" target="_blank">https://wandb.ai/heather-mck/nyc_airbnb/runs/2kxvo6l0</a><br/>
